# %%
import yaml
import pyodbc
from market_growth_analysis.etl.stagging import *
import pandas as pd

# Load the YAML file
with open('../../conf/local.yml', 'r') as f:
    config = yaml.safe_load(f)

# %%
balance_sheet_df = pd.read_csv("../../data/raw_01/balance-sheet.csv", index_col=0)
cash_flow_statement_df = pd.read_csv("../../data/raw_01/cash-flow-statement.csv", index_col=0)
# financial_ratios = pd.read_csv("../../data/raw_01/balance-sheet.csv")
income_statement_df = pd.read_csv("../../data/raw_01/income-statement.csv", index_col=0)
# prices_df = pd.read_csv("../../data/raw_01/prices.csv", index_col=0)

# %%
# convert 'Date' column to datetime format
balance_sheet_df['Date'] = pd.to_datetime(balance_sheet_df['Date'])
cash_flow_statement_df['Date'] = pd.to_datetime(cash_flow_statement_df['Date'])
income_statement_df['Date'] = pd.to_datetime(income_statement_df['Date'])

# %%
# Perform inner joins between the dataframes
merged_df = balance_sheet_df.merge(cash_flow_statement_df, on=['ticker', 'Date'], how='inner')
merged_df = merged_df.merge(income_statement_df, on=['ticker', 'Date'], how='inner')

# %% [markdown]
# # Check for duplicates

# %%
# extract year from the 'Date' column
merged_df['Year'] = merged_df['Date'].dt.year

# %%
# check for duplicates in the combination of 'ID_COMPANY' and 'Year' columns
duplicated_rows = merged_df.duplicated(subset=['ticker', 'Year'], keep=False)

# print the duplicated rows
merged_df[['ticker', 'Year', 'Date']].loc[duplicated_rows]
# Out:
#       ticker  Year       Date
# 2462    INDT  2020 2020-12-31
# 2463    INDT  2020 2020-11-30
# 2535    GMRE  2014 2014-12-31
# 2536    GMRE  2014 2014-08-31
# 2539    GMRE  2011 2011-12-31
# ...      ...   ...        ...
# 54381   CPTN  2021 2021-03-31
# 54383   CPTN  2019 2019-12-31
# 54384   CPTN  2019 2019-03-31
# 54902   MTVC  2021 2021-12-31
# 54903   MTVC  2021 2021-07-31
#
# [744 rows x 3 columns]

# %%
merged_df['ticker'].loc[duplicated_rows].unique()
# Out:
# array(['INDT', 'GMRE', 'CORR', 'JEF', 'CLBK', 'LC', 'GRNQ', 'LGHL', 'CSR',
#        'BRT', 'GYRO', 'AFBI', 'DFS', 'HVBC', 'EBMT', 'HASI', 'CZWI',
#        'FNWB', 'SSIC', 'RGEN', 'ALKS', 'VCEL', 'MYGN', 'ME', 'MDXG',
#        'AUTL', 'CMPX', 'EYPT', 'XAIR', 'ENOB', 'EIGR', 'APTO', 'HEPA',
#        'ORGS', 'SNCE', 'ABVC', 'ELOX', 'EDSA', 'ONVO', 'PULM', 'PTIX',
#        'SONN', 'AYTU', 'TENX', 'KTRA', 'ARTL', 'THMO', 'PRGO', 'EGRX',
#        'ORMP', 'KERN', 'NVIV', 'NEPT', 'ABCM', 'LIVN', 'KRMD', 'AXDX',
#        'EKSO', 'NSPR', 'HSDT', 'IMGN', 'SMMT', 'TARO', 'PROC', 'KALV',
#        'CTXR', 'VXRT', 'RVPH', 'RLMD', 'ADMP', 'PTE', 'LBPS', 'AMEH',
#        'DMTK', 'BTCY', 'NVOS', 'ACST', 'FCUV', 'UXIN', 'CXDO', 'IRNT',
#        'WDAY', 'AZPN', 'ASAN', 'ETWO', 'PL', 'ZFOX', 'PHUN', 'MRDB',
#        'VERB', 'TGAN', 'NOW', 'SCWX', 'RNLX', 'LICY', 'MG', 'GTEC', 'AEY',
#        'MSCI', 'HEAR', 'CLRO', 'AKTS', 'ASUR', 'CBAT', 'KLR', 'ESTE',
#        'TDW', 'CEQP', 'KLXE', 'DWSN', 'RNW', 'CRGY', 'CSAN', 'SEDG',
#        'VVPR', 'PFIE', 'KDP', 'BRFH', 'NUZE', 'MGPI', 'MMMB', 'VWE',
#        'TLRY', 'FRG', 'ELF', 'ADM', 'AVO', 'LVRO', 'BIOX', 'SMPL', 'SSU',
#        'AHG', 'BH', 'SPTN', 'JEWL', 'GPN', 'GB', 'GDOT', 'CRGO', 'SYM',
#        'KD', 'MIR', 'MARA', 'MDRX', 'INSE', 'SKIL', 'BLDE', 'PRST',
#        'ARQQ', 'NWTN', 'RTC', 'INPX', 'LKCO', 'EQOS', 'CRAI', 'BBCP',
#        'QRHC', 'IBEX', 'MOXC', 'RCRT', 'STAF', 'TISI', 'PLL', 'GSM', 'NB',
#        'AREC', 'GFI', 'RGLD', 'MOS', 'WRK', 'GNE', 'ZWS', 'AMCR', 'HTOO',
#        'VIEW', 'CRKN', 'RSVR', 'IMAQ', 'CDRO', 'GMGI', 'MSGS', 'AMC',
#        'MCS', 'LVO', 'GIL', 'ASO', 'POWW', 'LAZY', 'YVR', 'AACG', 'SPB',
#        'TCS', 'BV', 'VTOL', 'CYRX', 'CTRM', 'LDOS', 'AJRD', 'NOA', 'SKY',
#        'BLBD', 'MULN', 'AYRO', 'CENN', 'OSK', 'CHPT', 'DCFC', 'WPRT',
#        'CPTN', 'MTVC'], dtype=object)

# %%
merged_df['n_nan'] = merged_df.isna().sum(axis=1).astype(int)

# %%
# sort the dataframe by 'ID_COMPANY', 'Year' and the count of missing values
df_sorted = merged_df.sort_values(by=['ticker', 'Year', 'n_nan'])

# %%
# keep the first occurrence of each 'ID_COMPANY-Year' combination
df_unique = df_sorted.drop_duplicates(subset=['ticker', 'Year'], keep='first')

# %%
df_unique[df_unique['ticker']=='NUZE']
# Out:
#             Date  Cash On Hand  Receivables  Inventory  Pre-Paid Expenses  \
# 32850 2010-09-30           NaN          NaN        NaN                NaN
# 32848 2011-09-30        0.0001       0.0330        NaN                NaN
# 32846 2012-09-30        0.1655          NaN     0.0732             0.0149
# 32845 2013-09-30        1.1107       0.1529        NaN             0.0169
# 32844 2014-09-30        0.2382       0.0052     0.0509             0.0691
# 32843 2015-09-30        0.1077       0.0182     0.2018             0.0215
# 32842 2016-09-30        0.0406       0.0577     0.2064                NaN
# 32841 2017-09-30        0.3473       0.1563     0.2666                NaN
# 32840 2018-09-30        1.8067       0.1449     0.1349             0.0947
# 32839 2019-09-30        1.3260       0.5403     0.5010             0.3725
# 32838 2020-09-30        4.3985       0.1956     0.2454             0.6454
# 32837 2021-09-30       10.8160       0.5552     0.5735             0.4823
# 32836 2022-09-30        8.3151       0.3453     0.9480             0.5478
#
#        Other Current Assets  Total Current Assets  \
# 32850                   NaN                0.0080
# 32848                   NaN                0.0331
# 32846                   NaN                0.2537
# 32845                   NaN                1.2804
# 32844                   NaN                0.3633
# 32843                   NaN                0.3492
# 32842                0.0657                0.3704
# 32841                0.1323                0.9025
# 32840                0.0339                2.2150
# 32839                0.0005                2.7403
# 32838                   NaN                5.4849
# 32837                   NaN               12.4269
# 32836                   NaN               10.1561
#
#        Property, Plant, And Equipment  Long-Term Investments  \
# 32850                             NaN                    NaN
# 32848                             NaN                    NaN
# 32846                          0.0025                    NaN
# 32845                          0.0087                    NaN
# 32844                          0.0334                    NaN
# 32843                          0.1921                    NaN
# 32842                          0.1519                    NaN
# 32841                          0.2780                 0.0107
# 32840                          0.6744                    NaN
# 32839                          1.8756                    NaN
# 32838                          1.6683                 0.1833
# 32837                          0.6740                 0.1754
# 32836                          0.5251                 0.1696
#
#        Goodwill And Intangible Assets  ...  Basic Shares Outstanding  \
# 32850                             NaN  ...                       NaN
# 32848                          0.0000  ...                       NaN
# 32846                          0.0428  ...                    0.2898
# 32845                             NaN  ...                    0.3328
# 32844                             NaN  ...                    0.2871
# 32843                             NaN  ...                    0.2860
# 32842                             NaN  ...                    0.2931
# 32841                          0.0171  ...                    0.3063
# 32840                          0.0171  ...                    0.3499
# 32839                             NaN  ...                    0.3966
# 32838                             NaN  ...                    0.3966
# 32837                             NaN  ...                    0.4694
# 32836                          0.1400  ...                    0.5539
#
#        Shares Outstanding  Basic EPS  EPS - Earnings Per Share  \
# 32850                 NaN        NaN                    0.0000
# 32848                 NaN        NaN                    0.0000
# 32846              0.2898    -1.0491                   -1.0491
# 32845              0.3328    -3.1472                   -3.1472
# 32844              0.2871   -10.4906                  -10.4906
# 32843              0.2860    -5.2453                   -5.2453
# 32842              0.2931    -4.1962                   -4.1962
# 32841              0.3063    -5.2453                   -5.2453
# 32840              0.3499   -10.1399                  -10.1399
# 32839              0.3966   -30.7692                  -30.7692
# 32838              0.3966   -23.7762                  -23.7762
# 32837              0.4694   -39.5105                  -39.5105
# 32836              0.5539   -21.3287                  -21.3287
#
#                       industry            sector  company_full_name  \
# 32850  Beverages - Soft Drinks  Consumer Staples              Nuzee
# 32848  Beverages - Soft Drinks  Consumer Staples              Nuzee
# 32846  Beverages - Soft Drinks  Consumer Staples              Nuzee
# 32845  Beverages - Soft Drinks  Consumer Staples              Nuzee
# 32844  Beverages - Soft Drinks  Consumer Staples              Nuzee
# 32843  Beverages - Soft Drinks  Consumer Staples              Nuzee
# 32842  Beverages - Soft Drinks  Consumer Staples              Nuzee
# 32841  Beverages - Soft Drinks  Consumer Staples              Nuzee
# 32840  Beverages - Soft Drinks  Consumer Staples              Nuzee
# 32839  Beverages - Soft Drinks  Consumer Staples              Nuzee
# 32838  Beverages - Soft Drinks  Consumer Staples              Nuzee
# 32837  Beverages - Soft Drinks  Consumer Staples              Nuzee
# 32836  Beverages - Soft Drinks  Consumer Staples              Nuzee
#
#              country  Year  n_nan
# 32850  United States  2010     57
# 32848  United States  2011     41
# 32846  United States  2012     28
# 32845  United States  2013     26
# 32844  United States  2014     26
# 32843  United States  2015     24
# 32842  United States  2016     25
# 32841  United States  2017     15
# 32840  United States  2018     15
# 32839  United States  2019     16
# 32838  United States  2020     16
# 32837  United States  2021     18
# 32836  United States  2022     15
#
# [13 rows x 90 columns]

# %%
df_unique.to_csv("../../data/intermediate_02/financial-sheets.csv")
